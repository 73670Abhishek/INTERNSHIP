# %% [markdown]
# # Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %% [markdown]
# # In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\dell\anaconda3\lib\site-packages (4.21.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\dell\anaconda3\lib\site-packages (from selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in c:\users\dell\anaconda3\lib\site-packages (from selenium) (0.25.1)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\dell\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\dell\anaconda3\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\dell\anaconda3\lib\site-packages (from selenium) (4.11.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\dell\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\dell\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\dell\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\dell\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome()
driver.maximize_window()

# %%
driver.get("https://www.amazon.in/")

# %%
search_box = driver.find_element(By.ID,"twotabsearchtextbox")
product_name = input("product you wanna search for :")
search_box.send_keys(product_name)
# Out:
# product you wanna search for :mobile

# %%
search_box.send_keys(Keys.RETURN)

# %%
products_url = []
product_names = []
brand_names = []
prices = []
return_exchanges = []
expected_deliveries = []
availabilities = []

# %%
start = 0
end = 2
for page in range(start,end):
    time.sleep(3)
    
    product_url = driver.find_elements(By.XPATH,'//h2 [@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]/a')
    
    for i in product_url:
        url = i.get_attribute('href')
        products_url.append(url)
            
next_button = driver.find_element(By.XPATH,'//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div[29]/div/div/span/a[3]')
next_button.click()

# %%
for i in products_url:
    driver.get(i)
    
    #brand_name
    try:
        brand_name = driver.find_element(By.XPATH,'//*[@id="productOverview_feature_div"]/div/table/tbody/tr[1]/td[2]/span')
        brand_names.append(brand_name.text)
    except NoSuchElementException as e:
        brand_names.append("-")   
    
    #product_name
    try:
        product_name = driver.find_element(By.XPATH,'//h1 [@class="a-size-large a-spacing-none"] ')
        product_names.append(product_name.text)
    except NoSuchElementException as e:
        product_names.append("-") 
        
   #price
    try:
        price = driver.find_element(By.XPATH,'//*[@id="corePriceDisplay_desktop_feature_div"]/div[1]/span[3]/span[2]/span[2] ')
        prices.append(price.text)
    except NoSuchElementException as e:
        prices.append("-")  
        
    #availability
    try:
        availability = driver.find_element(By.XPATH,'//div  [@class="a-section a-spacing-none a-spacing-top-micro }"] ')
        availabilities.append(availability.text)
    except NoSuchElementException as e:
        availabilities.append("-") 
        
     #return_exchange
    try:
        exchanges = driver.find_element(By.XPATH,'//span [@class="a-size-small a-color-link a-text-normal"] ')
        return_exchanges.append(exchanges.text)
    except NoSuchElementException as e:
        exchanges.append("-") 
        
      #deliveries
    try:
        delivery = driver.find_element(By.XPATH,'//*[@id="mir-layout-DELIVERY_BLOCK-slot-SECONDARY_DELIVERY_MESSAGE_LARGE"]/span ')
        expected_deliveries.append(delivery.text)
    except NoSuchElementException as e:
        expected_deliveries.append("-")

# %%
print(len(products_url))
print(len(product_names))
print(len(brand_names))
print(len(prices))
print(len(return_exchanges))
print(len(expected_deliveries))
print(len(availabilities))
# Out:
# 44
# 44
# 44
# 44
# 44
# 44
# 44

# %%
df=pd.DataFrame({})
df['Product Urls']=products_url
df['Name of the product']=product_names
df['Brand']=brand_names
df['Price']=prices
df['Return/Exchange']=return_exchanges
df['Delivery details']=expected_deliveries
df['Availability']=availabilities
df
# Out:
#                                          Product Urls  \
# 0   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2   https://www.amazon.in/Stardust-Storage-Powered...
# 3   https://www.amazon.in/Starshine-Storage-Powere...
# 4   https://www.amazon.in/Samsung-sAMOLED-Display-...
# 5   https://www.amazon.in/realme-Storage-Chipset-C...
# 6   https://www.amazon.in/POCO-C65-Matte-Black-128...
# 7   https://www.amazon.in/Samsung-Waterfall-sAMOLE...
# 8   https://www.amazon.in/realme-Storage-Chipset-C...
# 9   https://www.amazon.in/Redmi-Jade-Black-6GB-128...
# 10  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 11  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
#
# 25  7 days Service Centre Replacement
# 26  7 days Service Centre Replacement
# 27  7 days Service Centre Replacement
# 28  7 days Service Centre Replacement
# 29                     Returns Policy
# 30  7 days Service Centre Replacement
# 31  7 days Service Centre Replacement
# 32  7 days Service Centre Replacement
# 33  7 days Service Centre Replacement
# 34  7 days Service Centre Replacement
# 35  7 days Service Centre Replacement
# 36  7 days Service Centre Replacement
# 37  7 days Service Centre Replacement
# 38                     Returns Policy
# 39  7 days Service Centre Replacement
# 40  7 days Service Centre Replacement
# 41  7 days Service Centre Replacement
# 42  7 days Service Centre Replacement
# 43  7 days Service Centre Replacement
#
#                                      Delivery details           Availability
# 0   Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 1                                                   -               In stock
# 2   Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 3   Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 4                                                   -               In stock
# 5   Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 6                                                   -               In stock
# 7                                                   -                      -
# 8   Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 9   Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 10  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 11  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 12  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 13                                                  -               In stock
# 14  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 15  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 16                                                  -                      -
# 17  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 18  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 19  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 20  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 21                                                  -  Only 1 left in stock.
# 22  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 23       Or fastest delivery Monday, 24 June. Details               In stock
# 24  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 25  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 26                                                  -               In stock
# 27  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 28                                                  -               In stock
# 29                                                  -                      -
# 30  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 31  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 32  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 33  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 34  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 35                                                  -               In stock
# 36  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 37  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 38                                                  -                      -
# 39  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 40  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 41  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 42  Or fastest delivery Tomorrow, 21 June. Order w...               In stock
# 43                                                  -  Only 1 left in stock.

# %% [markdown]
# # =========================================

# %% [markdown]
# # Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome()
driver.maximize_window()
driver.get("https://images.google.com/?gws_rd=ssl")

# %%
# List of keywords 
keywords = ['fruits', 'cars', 'machine learning', 'guitar', 'cakes']

# an empty list to store image URLs
image_data = []

# Index variable for keywords.
current_keyword_index = 0

# %%
while current_keyword_index < len(keywords):
    keyword = keywords[current_keyword_index]
    
    try:
        search_box = driver.find_element(By.XPATH, '//*[@id="APjFqb"]')
        search_box.clear()
        search_box.send_keys(keyword)
        search_box.send_keys(Keys.RETURN)
        time.sleep(5)

        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(10)

        images = driver.find_elements(By.TAG_NAME, 'img')[:15]

        keyword_image_urls = []
        for img in images:
            src = img.get_attribute('src')
            if src:
                keyword_image_urls.append(src)
                image_data.append({'Keyword': keyword, 'ImageURL': src})

        print(f"Keyword: {keyword}, Number of Image URLs: {len(keyword_image_urls)}, URLs: {keyword_image_urls}")

        

    except NoSuchElementException as e:
        print(f"element not found: {e}")
    except Exception as e:
        print(f"an error occurred: {e}")

    current_keyword_index += 1

    time.sleep(15)
# Out:
# Keyword: fruits, Number of Image URLs: 9, URLs: ['https://www.google.com/images/branding/googlelogo/2x/googlelogo_color_92x30dp.png', 'data:image/png;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQjFMkZSL1hpr26XrH9QtjNASgJLnLQt4djPTniV1coKp23n64ilR1x0phr&s', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSAwVVyW9tqZiZ9S9CWVf4sZvxfLp93nA69A2Q4ZG0A2Nos5TN9qvaz_yeI&s', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTX5KRGcCgN3KJkHzf3TKwgiRTxDyeyytsYdDbGYYfqSxPkrbltW5rVEpai&s']
# Keyword: cars, Number of Image URLs: 9, URLs: ['https://www.google.com/images/branding/googlelogo/2x/googlelogo_color_92x30dp.png', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSsEU7vEVhJkxMd_QtQ8wgxKggrIWN4nJDCi71ppHDM_LlTTCISMv55LFXJ&s', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS1IOdckB5lo9Li1BLZH9jb6ME4cOodV0_sVDjJeZgDMrfe_jzqqyjN_eTX&s', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSOPSlfpsmso8TBubX6o3pzbykNoPRdYLiQp1YZbLQRPi1vmRqhZR_-ddUj&s']
# Keyword: machine learning, Number of Image URLs: 9, URLs: ['https://www.google.com/images/branding/googlelogo/2x/googlelogo_color_92x30dp.png', 'data:image/jpeg;base64,...', 'data:image/png;base64,...', 'data:image/jpeg;base64,...', 'data:image/png;base64,...', 'data:image/png;base64,...', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSFHwM0oGpbidPDcPfiLLRk8VfnODXf67f5xaicYPD2HbKMZUbVfKvKS5AK&s', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTFtHtwPqGlwFPbmBvbzNuc4Nu5kgNWXoQBmOplACgT6RSzkndeqVkBHsr0&s', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTxX1AGNov94pP3qJnM_1MNSkSjuvuW1tuGORwKuj6E2vW-olotVYEJA4Bc&s']
# Keyword: guitar, Number of Image URLs: 9, URLs: ['https://www.google.com/images/branding/googlelogo/2x/googlelogo_color_92x30dp.png', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTsWcYsa3p9vUk0vEfbT5I4J8552wNNH-KnP8Kdb-WWQLT0rRIgoWVt8LoZ&s', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQXvmV49ebiQzPPIi1_89XaGj2ApHMX21Dz6qrLB3y5byH_by6MYd9BBT46&s', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSlE6weEuZRB8I1ltXkdpOWMbBXDjaX4SKRNL_LmZ0FeM2HY0AKbE9aC86y&s']
# Keyword: cakes, Number of Image URLs: 9, URLs: ['https://www.google.com/images/branding/googlelogo/2x/googlelogo_color_92x30dp.png', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ9xAPsd9qWnETXgM4jc73TXVXY6INUSv3c__t4mpxj_Mp-TvAmBeod839Q&s', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSiLwbA6E_jCe8zIgJEEb9gUYJANEtm3LBulU0rNl3v8wi8BoaWRs8rq_Tl&s', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQbRgPoGwBun3eblOFI6Qv7ZtOTlP6GTxsXWcRPeRArhTZE3Xh_hW-49hoW&s']

# %%
df = pd.DataFrame(image_data)

# %%
print(df)

#quit driver
driver.quit()
# Out:
#              Keyword                                           ImageURL
# 0             fruits  https://www.google.com/images/branding/googlel...
# 1             fruits  ......
# 2             fruits  ......
# 3             fruits  ......
# 4             fruits  ......
# 5             fruits  ......
# 6             fruits  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 7             fruits  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 8             fruits  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 9               cars  https://www.google.com/images/branding/googlel...
# 10              cars  ......
# 11              cars  ......
# 12              cars  ......
# 13              cars  ......
# 14              cars  ......
# 15              cars  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 16              cars  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 17              cars  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 18  machine learning  https://www.google.com/images/branding/googlel...
# 19  machine learning  ......
# 20  machine learning  ......
# 21  machine learning  ......
# 22  machine learning  ......
# 23  machine learning  ......
# 24  machine learning  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 25  machine learning  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 26  machine learning  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 27            guitar  https://www.google.com/images/branding/googlel...
# 28            guitar  ......
# 29            guitar  ......
# 30            guitar  ......
# 31            guitar  ......
# 32            guitar  ......
# 33            guitar  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 34            guitar  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 35            guitar  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 36             cakes  https://www.google.com/images/branding/googlel...
# 37             cakes  ......
# 38             cakes  ......
# 39             cakes  ......
# 40             cakes  ......
# 41             cakes  ......
# 42             cakes  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 43             cakes  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 44             cakes  https://encrypted-tbn0.gstatic.com/images?q=tb...

# %% [markdown]
# # ========================================================================

# %% [markdown]
# # Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import warnings
from selenium.common.exceptions import NoSuchElementException
warnings.filterwarnings('ignore')

# %%
driver = webdriver.Chrome()
driver.maximize_window()

# %%
driver.get("https://www.flipkart.com/")

# %%
search_box = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[1]/div/div/div/div/div[1]/div/div/div/div[1]/div[1]/header/div[1]/div[2]/form/div/div/input')
search_box.send_keys('smartphone')
search_box.send_keys(Keys.RETURN)

# %%
product_url = []
brand_name= []
smartphone_name = []
color = []
ram = []
storage_rom = []
primary_camera = []
secondary_camera = []
display_size = []
battery_capacity = []
price = []

# %%
products_url = driver.find_elements(By.XPATH,'//div [@class="tUxRFH"]/a')
    
for i in products_url:
    url = i.get_attribute('href')
    product_url.append(url)

# %%
for i in product_url:
    driver.get(i)
    
    #brand_name
    try:
        brands_name = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[1]/div[1]/div/div[4]/a')
        brand_name.append(brands_name.text)
    except NoSuchElementException as e:
        brand_name.append("-")   
    
    #smartphone_name
    try:
        smartphones_name = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div/div[1]/table/tbody/tr[3]/td[2]/ul/li' )
        smartphone_name.append(smartphones_name.text)
    except NoSuchElementException as e:
        smartphone_name.append("-") 
        
   #price
    try:
        prices = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[2]/div/div[4]/div[1]/div/div[1]')
        price.append(prices.text)
    except NoSuchElementException as e:
        price.append("-")  
        
    #color
    try:
        colors = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div/div[1]/table/tbody/tr[4]/td[2]/ul/li ')
        color.append(colors.text)
    except NoSuchElementException as e:
        color.append("-") 
        
     #ram
    try:
        ram_m = driver.find_element(By.XPATH,"//td[@class='Izz52n col col-9-12']//li[text()='8 GB']")
        ram.append(ram_m.text)
    except NoSuchElementException as e:
        ram.append("-") 
        
      #rom
    try:
        rom = driver.find_element(By.XPATH,"//td[@class='Izz52n col col-9-12']//li[text()='128 GB']")
        storage_rom.append(rom.text)
    except NoSuchElementException as e:
        storage_rom.append("-")  
        
       #p_camera
    try:
        p_camera = driver.find_element(By.XPATH,"//td[@class='Izz52n col col-9-12']//li[text()='200MP (OIS) + 8MP + 2MP']")
        primary_camera.append(p_camera.text)
    except NoSuchElementException as e:
        primary_camera.append("-")  
        
       #s_camera
    try:
        s_camera = driver.find_element(By.XPATH,"//td[@class='Izz52n col col-9-12']//li[text()='16MP Front Camera']")
        secondary_camera.append(s_camera.text)
    except NoSuchElementException as e:
        secondary_camera.append("-")    
        
        #d_size
    try:
        d_size = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[2] ')
        display_size.append(d_size.text)
    except NoSuchElementException as e:
        display_size.append("-")   
        
        #battery_c
    try:
        battery_c = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[4]')
        battery_capacity.append(battery_c .text)
    except NoSuchElementException as e:
        battery_capacity.append("-")

# %%
print(len(product_url),len(brand_name),len(smartphone_name),len(color),len(ram),len(storage_rom),len(primary_camera),len(secondary_camera),len(display_size),len(battery_capacity),len(price))
# Out:
# 24 24 24 24 24 24 24 24 24 24 24

# %%
df=pd.DataFrame({})
df['Product Urls']=product_url
df['Name of the product']=smartphone_name
df['Brand']=brand_name
df['Price']=price
df['Color']=color
df['RAM']=ram
df['ROM']=storage_rom
df['Primary_cam']=primary_camera
df['Secondary_cam']=secondary_camera
df['Battery']=battery_capacity
df['Display']=display_size
df
# Out:
#                                          Product Urls Name of the product  \
# 0   https://www.flipkart.com/realme-gt-6-fluid-sil...                GT 6
# 1   https://www.flipkart.com/xiaomi-14-civi-shadow...             14 CIVI
# 2   https://www.flipkart.com/motorola-g34-5g-ocean...              G34 5G
# 3   https://www.flipkart.com/samsung-galaxy-f14-5g...       Galaxy F14 5G
  4700 mAh Battery           16.64 cm (6.55 inch) Display
# 2                 5000 mAh Battery        16.51 cm (6.5 inch) HD+ Display
# 3              -  6000 mAh Battery   16.76 cm (6.6 inch) Full HD+ Display
# 4                 5000 mAh Battery        16.51 cm (6.5 inch) HD+ Display
# 5              -  5000 mAh Battery  17.25 cm (6.79 inch) Full HD+ Display
# 6              -  4700 mAh Battery           16.64 cm (6.55 inch) Display
# 7              -  4700 mAh Battery           16.64 cm (6.55 inch) Display
# 8              -  6000 mAh Battery   16.76 cm (6.6 inch) Full HD+ Display
# 9              -  6000 mAh Battery   16.76 cm (6.6 inch) Full HD+ Display
# 10             -  4700 mAh Battery           16.64 cm (6.55 inch) Display
# 11             -  4700 mAh Battery           16.64 cm (6.55 inch) Display
# 12                5000 mAh Battery        16.51 cm (6.5 inch) HD+ Display
# 13             -  5000 mAh Battery       17.12 cm (6.74 inch) HD+ Display
# 14             -                 -                                      -
# 15             -                 -                                      -
# 16             -  4700 mAh Battery           16.64 cm (6.55 inch) Display
# 17             -                 -                                      -
# 18                6000 mAh Battery   16.51 cm (6.5 inch) Full HD+ Display
# 19                6000 mAh Battery   16.51 cm (6.5 inch) Full HD+ Display
# 20             -  5000 mAh Battery       17.12 cm (6.74 inch) HD+ Display
# 21             -  5000 mAh Battery        16.76 cm (6.6 inch) HD+ Display
# 22             -                 -                                      -
# 23             -  5000 mAh Battery       17.12 cm (6.74 inch) HD+ Display

# %% [markdown]
# # ===============================================================

# %% [markdown]
# # Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

# %%
driver = webdriver.Chrome()
driver.maximize_window()

# %%
driver.get("https://www.google.com/maps")

# %%
# input the city 
city_name = input("Enter the city name: ")
# Out:
# Enter the city name: bangalore

# %%
search_box = WebDriverWait(driver, 10).until(
    EC.presence_of_element_located((By.XPATH, "//input[@id='searchboxinput']"))
)
search_box.clear()
search_box.send_keys(city_name)
search_box.send_keys(Keys.RETURN)

# %%
#url of current_city
current_url = driver.current_url

# %%
print(current_url)
# Out:
# https://www.google.com/maps/place/Bengaluru,+Karnataka/@12.9537902,77.3012693,10z/data=!3m1!4b1!4m6!3m5!1s0x3bae1670c9b44e6d:0xf8dfc3e8517e4fe0!8m2!3d12.9715987!4d77.5945627!16zL20vMDljMTc?entry=ttu

# %%
if '@' in current_url:
    url_parts = current_url.split('@')[1].split(',')
    latitude = url_parts[0]
    longitude = url_parts[1]
    print(f"Coordinates of {city_name}:")
    print(f"Latitude: {latitude}")
    print(f"Longitude: {longitude}")
else:
    print("Could not parse the coordinates from the URL.")
# Out:
# Coordinates of bangalore:
# Latitude: 12.9537902
# Longitude: 77.3012693

# %% [markdown]
# # =================================================================

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import warnings
from selenium.common.exceptions import NoSuchElementException
warnings.filterwarnings('ignore')

# %%
driver = webdriver.Chrome()
driver.maximize_window()
time.sleep(3)

# %%
driver.get("https://www.digit.in/top-products/best-gaming-laptops-40.html")

# %%
products_url = []
product_name = []
operating_system= []
processor = []
display_size = []

# %%
product_urls = driver.find_elements(By.XPATH,'//div [@class="rh_gr_top_middle mb10 colored_rate_bar"]/h3/a ')
    
for i in product_urls:
    url = i.get_attribute('href')
    products_url.append(url)

# %%
print(len(products_url))
# Out:
# 10

# %%
for i in products_url:
    driver.get(i)
    
    
    
    #product_name
    try:
        products_name = driver.find_element(By.XPATH,'//*[@id="section-woo-custom-wheretobuy"]/div[2]/div[1]/div/div[2]/div[2]/div/a')
        product_name.append(products_name.text)
    except NoSuchElementException as e:
        product_name.append("-") 
        
   #processor
    try:
        processors = driver.find_element(By.XPATH,'//*[@id="section-additional_information"]/div[2]/table/tbody/tr[10]/td/table/tbody/tr[2]/td/p')
        processor.append(processors.text)
    except NoSuchElementException as e:
        processor.append("-")  
  
        
     #operating_systems
    try:
        operating_systems = driver.find_element(By.XPATH, '//td [@class="woocommerce-product-attributes-item__value"]/p ')
        operating_system.append(operating_systems.text)
    except NoSuchElementException as e:
        operating_system.append("-") 
        
      #display_sizes
    try:
        display_sizes = driver.find_element(By.XPATH, '//*[@id="section-additional_information"]/div[2]/table/tbody/tr[4]/td/table/tbody/tr/td/p')
        display_size.append(display_sizes.text)
    except NoSuchElementException as e:
        display_size.append("-")

# %%
print(len(product_name),len(operating_system),len(display_size),len(processor))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({})
df['Product_URL']=products_url
df['Processor']=processor
df['Product_Name']=product_name
df['Operating_System']=operating_system
df['Display_Size']=display_size
df
# Out:
#                                          Product_URL  \
# 0  https://www.digit.in/laptops/msi-titan-gt77-hx...
# 1  https://www.digit.in/laptops/asus-rog-strix-sc...
# 2  https://www.digit.in/laptops/msi-raider-ge78hx...
# 3  https://www.digit.in/laptops/asus-rog-strix-sc...
# 4  https://www.digit.in/laptops/lenovo-legion-pro...
# 5  https://www.digit.in/laptops/omen-by-hp-17-ck2...
# 6  https://www.digit.in/laptops/dell-alienware-m1...
# 7  https://www.digit.in/laptops/dell-alienware-x1...
# 8  https://www.digit.in/laptops/msi-raider-ge67hx...
# 9  https://www.digit.in/laptops/acer-predator-hel...
#
#                         Processor  \
# 0                              24
# 1                           36 MB
# 2  13th Gen Intel Core i9-13980HX
# 3                           36 MB
# 4         NVIDIA GeForce RTX 4090
# 5                           36 MB
# 6                           36 MB
# 7                           24 MB
# 8      NVIDIA GeForce RTX 3080 Ti
# 9  13th Gen Intel Core i9-13900HX
#
#                                         Product_Name Operating_System  \
# 0  MSI Titan GT77 HX, Intel 13th Gen. i9-13980HX,...  Windows 11 Home
# 1  ASUS ROG Strix Scar 16, Intel® Core™ i9 14900H...  Windows 11 Home
# 2  MSI Raider GE78HX, Intel 13th Gen. i9-13980HX,...  Windows 11 Home
# 3  ASUS ROG Strix Scar 18 (2023), Intel Core i9 1...  Windows 11 Home
# 4  Lenovo Legion Pro 7i 16" QHD+ 500nits Gaming L...  Windows 11 Home
# 5  HP OMEN Gaming Laptop, 13th Gen Intel Core i9-...  Windows 11 Home
# 6  RAYA Silicone Keyboard Skin Cover for Dell Ali...  Windows 11 Home
# 7  Dell Alienware X16 R1 Gaming, Intel Core i9-13...  Windows 11 Home
# 8  MSI Raider GE67HX, Intel 12th Gen. i9-12900HX,...  Windows 11 Home
# 9  Acer Predator Helios 16 Gaming Laptop (Intel C...  Windows 11 Home
#
#   Display_Size
# 0         17.3
# 1           16
# 2           17
# 3           18
# 4           16
# 5         17.3
# 6           18
# 7           16
# 8         15.6
# 9           16
